# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\polpi\Desktop\data science\assignments\PCA\wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
#        'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
#        'Dilution', 'Proline'],
#       dtype='object')

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for col in df:
    plt.figure(figsize=(5,5))
    plt.hist(df[col],bins=10,color='green')
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
for col in df:
    plt.figure(figsize=(5,5))
    sns.boxplot(df[col],color='green')
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
for col in df:
    plt.figure(figsize=(5, 5))
    sns.kdeplot(df[col], color='green', shade=True)
    plt.title(f"Density Plot of {col}")
    plt.xlabel(col)
    plt.ylabel("Density")
    plt.show()
# Out:
# C:\Users\polpi\AppData\Local\Temp\ipykernel_19920\550553164.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], color='green', shade=True)
# C:\Users\polpi\AppData\Local\Temp\ipykernel_19920\550553164.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], color='green', shade=True)
# C:\Users\polpi\AppData\Local\Temp\ipykernel_19920\550553164.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col], color='green', shade=True)
# C:\Users\polpi\AppData\Local\Temp\ipykernel_19920\550553164.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x1=df.drop('Type',axis=1)
y=df['Type']
scaled_df=ss.fit_transform(df)
x=pd.DataFrame(scaled_df,columns=df.columns)
x
# Out:
#          Type   Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0   -1.213944  1.518613 -0.562250  0.232053   -1.169593   1.913905  0.808997
# 1   -1.213944  0.246290 -0.499413 -0.827996   -2.490847   0.018145  0.568648
# 2   -1.213944  0.196879  0.021231  1.109334   -0.268738   0.088358  0.808997
# 3   -1.213944  1.691550 -0.346811  0.487926   -0.809251   0.930918  2.491446
# 4   -1.213944  0.295700  0.227694  1.840403    0.451946   1.281985  0.808997
# ..        ...       ...       ...       ...         ...        ...       ...
# 173  1.373864  0.876275  2.974543  0.305159    0.301803  -0.332922 -0.985614
# 174  1.373864  0.493343  1.412609  0.414820    1.052516   0.158572 -0.793334
# 175  1.373864  0.332758  1.744744 -0.389355    0.151661   1.422412 -1.129824
# 176  1.373864  0.209232  0.227694  0.012732    0.151661   1.422412 -1.033684
# 177  1.373864  1.395086  1.583165  1.365208    1.502943  -0.262708 -0.392751
#
# ...

# %%
from sklearn.decomposition import PCA
import numpy as np
pca = PCA()
x_pca = pca.fit_transform(x)

explained_variance = pca.explained_variance_ratio_

plt.figure(figsize=(10, 5))
plt.plot(np.cumsum(explained_variance), marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance by Principal Components')
plt.grid(True)
plt.show()

# %%
optimal_components = np.argmax(np.cumsum(explained_variance) >= 0.95) + 1
print(f"Optimal number of principal components: {optimal_components}")

pca_optimal = PCA(n_components=optimal_components)
x_pca_transformed = pca_optimal.fit_transform(x)

print("Transformed Data (First 5 rows):")
x_pca_transformed[:5]
# Out:
# Optimal number of principal components: 10
# Transformed Data (First 5 rows):
# array([[-3.5229339 , -1.45309844, -0.16479549, -0.01327282,  0.73734536,
#         -0.30071618,  0.57387557,  0.05563728, -0.45876506,  1.06556955],
#        [-2.52885806,  0.33001925, -2.02670665, -0.41714436, -0.28321373,
#         -0.88430941, -0.02971648,  1.01037189,  0.21880609, -0.02018203],
#        [-2.78502898, -1.03693595,  0.9832377 ,  0.66423241, -0.38756497,
#          0.46884161,  0.4883054 , -0.26895705,  1.22276949, -0.10624913],
#        [-3.92258841, -2.76821026, -0.17496817,  0.56508782, -0.32435971,
#          0.26261642, -0.39836411,  0.61884369, -0.11465832,  0.10767113],
#        [-1.40751111, -0.86777309,  2.02582949, -0.4409058 ,  0.22794925,
#         -0.59376213,  0.44787555,  0.4349373 , -0.26154774,  0.11243432]])

# %%
X = pd.DataFrame(x_pca_transformed, columns=[f"PC{i+1}" for i in range(x_pca_transformed.shape[1])])
X
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0   -3.522934 -1.453098 -0.164795 -0.013273  0.737345 -0.300716  0.573876
# 1   -2.528858  0.330019 -2.026707 -0.417144 -0.283214 -0.884309 -0.029716
# 2   -2.785029 -1.036936  0.983238  0.664232 -0.387565  0.468842  0.488305
# 3   -3.922588 -2.768210 -0.174968  0.565088 -0.324360  0.262616 -0.398364
# 4   -1.407511 -0.867773  2.025829 -0.440906  0.227949 -0.593762  0.447876
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  3.627996 -2.206617 -0.343668  0.751705 -1.004109 -1.143155  0.843455
# 174  2.942729 -1.752263  0.207480  0.399381  0.154223 -0.062465  0.139947
# 175  3.027272 -2.756040 -0.940803  0.607758  1.128136  0.005290  0.733026
# 176  2.755222 -2.293784 -0.550474 -0.391570  1.067083  1.012562  0.755423
# 177  3.496336 -2.760608  1.013151  0.349630 -1.005136  0.377223  0.015307
#
#           PC8       PC9      PC10
# 0    0.055637 -0.458765  1.065570
# ...

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\polpi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\polpi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\polpi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
kmeans = KMeans(n_clusters = 5, init = "k-means++", random_state = 42)
y_kmeans = kmeans.fit_predict(scaled_df)
y_kmeans
# Out:
# C:\Users\polpi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\polpi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 4, 0, 4, 0,
#        0, 0, 4, 3, 4, 0, 4, 3, 0, 4, 0, 4, 3, 0, 0, 0, 4, 1, 0, 0, 4, 4,
#        4, 4, 4, 4, 4, 0, 0, 3, 3, 0, 0, 0, 0, 4, 0, 0, 0, 4, 0, 4, 0, 0,
# ...

# %%
plt.scatter(scaled_df[y_kmeans == 0, 0], scaled_df[y_kmeans == 0, 1], s=60, c='red', label='Cluster1')
plt.scatter(scaled_df[y_kmeans == 1, 0], scaled_df[y_kmeans == 1, 1], s=60, c='blue', label='Cluster2')
plt.scatter(scaled_df[y_kmeans == 2, 0], scaled_df[y_kmeans == 2, 1], s=60, c='green', label='Cluster3')
plt.scatter(scaled_df[y_kmeans == 3, 0], scaled_df[y_kmeans == 3, 1], s=60, c='violet', label='Cluster4')
plt.scatter(scaled_df[y_kmeans == 4, 0], scaled_df[y_kmeans == 4, 1], s=60, c='yellow', label='Cluster5')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='black', label='Centroids')

plt.legend()
plt.show()

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

sil_score = silhouette_score(scaled_df, y_kmeans)
print(f"Silhouette Score: {sil_score}")

db_index = davies_bouldin_score(scaled_df, y_kmeans)
print(f"Davies-Bouldin Index: {db_index}")

print("These two scores tells us how good the clusters have been separated. From these scores we can deduce that the clustering \nis not great and has good amount of overlapping.")
# Out:
# Silhouette Score: 0.25452770488211524
# Davies-Bouldin Index: 1.7321846131079048
# These two scores tells us how good the clusters have been separated. From these scores we can deduce that the clustering
# is not great and has good amount of overlapping.

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\polpi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\polpi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\polpi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
kmeans = KMeans(n_clusters = 5, init = "k-means++", random_state = 42)
y_kmeans = kmeans.fit_predict(X)
y_kmeans
# Out:
# C:\Users\polpi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\polpi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 4, 4, 4, 0, 4, 0,
#        0, 0, 4, 3, 4, 0, 4, 3, 0, 4, 0, 4, 3, 0, 0, 0, 4, 1, 0, 0, 4, 4,
#        4, 4, 4, 4, 4, 0, 0, 3, 3, 0, 0, 0, 0, 4, 0, 0, 0, 4, 4, 4, 0, 0,
# ...

# %%
plt.scatter(X.iloc[y_kmeans == 0, 0], X.iloc[y_kmeans == 0, 1], s=60, c='red', label='Cluster1')
plt.scatter(X.iloc[y_kmeans == 1, 0], X.iloc[y_kmeans == 1, 1], s=60, c='blue', label='Cluster2')
plt.scatter(X.iloc[y_kmeans == 2, 0], X.iloc[y_kmeans == 2, 1], s=60, c='green', label='Cluster3')
plt.scatter(X.iloc[y_kmeans == 3, 0], X.iloc[y_kmeans == 3, 1], s=60, c='violet', label='Cluster4')
plt.scatter(X.iloc[y_kmeans == 4, 0], X.iloc[y_kmeans == 4, 1], s=60, c='yellow', label='Cluster5')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='black', label='Centroids')

plt.legend()
plt.show()

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

sil_score = silhouette_score(X, y_kmeans)
print(f"Silhouette Score: {sil_score}")

db_index = davies_bouldin_score(X, y_kmeans)
print(f"Davies-Bouldin Index: {db_index}")
# Out:
# Silhouette Score: 0.27047332770178634
# Davies-Bouldin Index: 1.65617192738057

# %%
print("These two scores tells us how good the clusters have been separated. From these scores we can deduce that the clustering \nis not great and has good amount of overlapping.")
# Out:
# These two scores tells us how good the clusters have been separated. From these scores we can deduce that the clustering
# is not great and has good amount of overlapping.

# %%
print("The initial clustering using the original dataset produced a cluster with a lot of overlap and at discrete lines")
print("However, after PCA, the clusters were better. Though there were a number of overlaps, the clusters were identifiable.\nBut the clustering scores only improved slightly post PCA model fitting.")
print('')
print("PCA can often enhance clustering by reducing noise and focusing on the most informative components.")
print("PCA reduces the dimensionality, making the clustering algorithm run faster due to fewer features.")
print("Although these points gives a better clustering, there may be cases where essential details for clustering \nare lost during dimensionality reduction, leading to worse clustering performance.")
# Out:
# The initial clustering using the original dataset produced a cluster with a lot of overlap and at discrete lines
# However, after PCA, the clusters were better. Though there were a number of overlaps, the clusters were identifiable.
# But the clustering scores only improved slightly post PCA model fitting.
#
# PCA can often enhance clustering by reducing noise and focusing on the most informative components.
# PCA reduces the dimensionality, making the clustering algorithm run faster due to fewer features.
# Although these points gives a better clustering, there may be cases where essential details for clustering
# are lost during dimensionality reduction, leading to worse clustering performance.

# %%
print("To summarise this assignment, using PCA for transforming the data, before clustering produced much better clusters as \ncompared to clusters formed from the original data.")
print("Data with high dimensionality can be transformed using PCA to reduce the dimensions. \nPCA also reduces noise from the data. Therefore, a combined approach is much better.")
print("")
print("There are number of use cases of PCA: When dealing with high dimensional datasets, PCA can be reduce dimensionality.")
print("PCA improves model performance by reducing noise. A combination of PCA with clustering will be extremely helpful when:\nThe dataset is noisy,\nThe dataset has high no. of dimensions.")
# Out:
# To summarise this assignment, using PCA for transforming the data, before clustering produced much better clusters as
# compared to clusters formed from the original data.
# Data with high dimensionality can be transformed using PCA to reduce the dimensions.
# PCA also reduces noise from the data. Therefore, a combined approach is much better.
#
# There are number of use cases of PCA: When dealing with high dimensional datasets, PCA can be reduce dimensionality.
# PCA improves model performance by reducing noise. A combination of PCA with clustering will be extremely helpful when:
# The dataset is noisy,
# The dataset has high no. of dimensions.
